# %%
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt



lambda1=3 #Número médio de requisições
N=100000 #Numero de amostras
value=2
count=0
av=np.array([])
x=np.random.uniform(0,1,N)
for ix in x:
    i = 0
    pr = np.exp(-lambda1)
    F=pr
    while ix>=F:
        pr=lambda1/(i+1)*pr
        F = F + pr
        i = i + 1;
    a1=i
    av=np.append(av,a1)


print(av)
for binvalue in av:
    if binvalue>=value:
        count=count+1
prob=count/N
print("a probabilidade e",prob)
plt.hist(x,bins=1000)
plt.show()
# Out:
# [1. 5. 3. ... 2. 2. 3.]
# a probabilidade e 0.80118
